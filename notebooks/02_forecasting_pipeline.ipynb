# %% [markdown]
# # Forecasting Pipeline
#
# This notebook runs the package-based forecasting workflow and writes a DACON submission file.

# %%
from pathlib import Path

from lg_online_sales_forecasting import ForecastConfig, run_forecast

config = ForecastConfig(
    data_dir=Path("data"),
    output_path=Path("submissions/sales_forecast_submission.csv"),
    random_state=42,
)

submission = run_forecast(config)
submission.head()
